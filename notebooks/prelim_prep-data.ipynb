# %% [markdown]
# # Step: Downloading the dataset
#
# To begin, you must connect to runtime and have an api token from kaggle saved in your immediate directory of Google Drive in order to access the dataset directly through CLI

# %%
#@title Run this cell to mount Google Drive and get `kaggle.json` from personal directory

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Run this cell to download the competition dataset to notebook directory

! pip install kaggle
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle competitions download nfl-big-data-bowl-2025
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)
# Downloading nfl-big-data-bowl-2025.zip to /content
#  99% 1.13G/1.14G [00:11<00:00, 93.7MB/s]
# 100% 1.14G/1.14G [00:11<00:00, 102MB/s]

# %% [markdown]
# ### Install SportsTransformers_utils provided by SumerSports

# %%
file_location = '/content/nfl-big-data-bowl-2025.zip'

# %%
# !unzip {file_location}
# Out:
# Archive:  /content/nfl-big-data-bowl-2025.zip
#   inflating: games.csv
#   inflating: player_play.csv
#   inflating: players.csv
#   inflating: plays.csv
#   inflating: tracking_week_1.csv
#   inflating: tracking_week_2.csv
#   inflating: tracking_week_3.csv
#   inflating: tracking_week_4.csv
#   inflating: tracking_week_5.csv
#   inflating: tracking_week_6.csv
#   inflating: tracking_week_7.csv
#   inflating: tracking_week_8.csv
#   inflating: tracking_week_9.csv

# %% [markdown]
# # Stage: Prep Data

# %% [markdown]
# ## Load in the data files from the data set

# %%
from argparse import ArgumentParser
from pathlib import Path

import polars as pl
import os

import random

# TEMPORARY CHANGE
INPUT_DATA_DIR = Path("./")
OUT_DIR = Path("/content/drive/My Drive/bdb-2025/split_prepped_data")

OUT_DIR.mkdir(parents=True, exist_ok=True) # Create directory if it doesn't exist

# %%
def get_players_df() -> pl.DataFrame:
    """
    Load player-level data and preprocesses features.

    Returns:
        pl.DataFrame: Preprocessed player data with additional features.
    """
    return (
        pl.read_csv(INPUT_DATA_DIR / "players.csv", null_values=["NA", "nan", "N/A", "NaN", ""])
        .with_columns(
            height_inches=(
                pl.col("height").str.split("-").map_elements(lambda s: int(s[0]) * 12 + int(s[1]), return_dtype=int)
            )
        )
        .with_columns(
            weight_Z=(pl.col("weight") - pl.col("weight").mean()) / pl.col("weight").std(),
            height_Z=(pl.col("height_inches") - pl.col("height_inches").mean()) / pl.col("height_inches").std(),
        )
    )

def get_plays_df() -> pl.DataFrame:
    """
    Load play-level data and preprocesses features.

    Returns:
        pl.DataFrame: Preprocessed play data with additional features.
    """
    return pl.read_csv(INPUT_DATA_DIR / "plays.csv", null_values=["NA", "nan", "N/A", "NaN", ""]).with_columns(
        distanceToGoal=(
            pl.when(pl.col("possessionTeam") == pl.col("yardlineSide"))
            .then(100 - pl.col("yardlineNumber"))
            .otherwise(pl.col("yardlineNumber"))
        )
    )

def get_tracking_df() -> pl.DataFrame:
    """
    Load tracking data and preprocesses features. Notably, exclude rows representing the football's movement.

    Returns:
        pl.DataFrame: Preprocessed tracking data with additional features.
    """
    # don't include football rows for this project.
    # NOTE: Only processing week 1 for the sake of time.  Change "1" to "*" to process all weeks
    return pl.read_csv(INPUT_DATA_DIR / "tracking_week_1.csv", null_values=["NA", "nan", "N/A", "NaN", ""]).filter(
        pl.col("displayName") != "football"
    )

# %%
# Load in raw data
print("Load players")
players_df = get_players_df()
print("Load plays")
plays_df = get_plays_df()
print("Load tracking")
tracking_df = get_tracking_df()
print("tracking_df rows:", len(tracking_df))
# Out:
# Load players
# Load plays
# Load tracking
# tracking_df rows: 6795800

# %%
players_df.head()
# Out:
# shape: (5, 10)
# ┌───────┬────────┬────────┬────────────┬───┬───────────────┬───────────────┬───────────┬───────────┐
# │ nflId ┆ height ┆ weight ┆ birthDate  ┆ … ┆ displayName   ┆ height_inches ┆ weight_Z  ┆ height_Z  │
# │ ---   ┆ ---    ┆ ---    ┆ ---        ┆   ┆ ---           ┆ ---           ┆ ---       ┆ ---       │
# │ i64   ┆ str    ┆ i64    ┆ str        ┆   ┆ str           ┆ i64           ┆ f64       ┆ f64       │
# ╞═══════╪════════╪════════╪════════════╪═══╪═══════════════╪═══════════════╪═══════════╪═══════════╡
# │ 25511 ┆ 6-4    ┆ 225    ┆ 1977-08-03 ┆ … ┆ Tom Brady     ┆ 76            ┆ -0.439612 ┆ 0.658795  │
# │ 29550 ┆ 6-4    ┆ 328    ┆ 1982-01-22 ┆ … ┆ Jason Peters  ┆ 76            ┆ 1.740005  ┆ 0.658795  │
# │ 29851 ┆ 6-2    ┆ 225    ┆ 1983-12-02 ┆ … ┆ Aaron Rodgers ┆ 74            ┆ -0.439612 ┆ -0.096594 │
# │ 30842 ┆ 6-6    ┆ 267    ┆ 1984-05-19 ┆ … ┆ Marcedes      ┆ 78            ┆ 0.449164  ┆ 1.414183  │
# │       ┆        ┆        ┆            ┆   ┆ Lewis         ┆               ┆           ┆           │
# │ 33084 ┆ 6-4    ┆ 217    ┆ 1985-05-17 ┆ … ┆ Matt Ryan     ┆ 76            ┆ -0.608903 ┆ 0.658795  │
# └───────┴────────┴────────┴────────────┴───┴───────────────┴───────────────┴───────────┴───────────┘

# %%
plays_df.head()
# Out:
# shape: (5, 51)
# ┌────────────┬────────┬────────────┬─────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ gameId     ┆ playId ┆ playDescri ┆ quarter ┆ … ┆ pff_runPas ┆ pff_passCo ┆ pff_manZo ┆ distanceT │
# │ ---        ┆ ---    ┆ ption      ┆ ---     ┆   ┆ sOption    ┆ verage     ┆ ne        ┆ oGoal     │
# │ i64        ┆ i64    ┆ ---        ┆ i64     ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆        ┆ str        ┆         ┆   ┆ i64        ┆ str        ┆ str       ┆ i64       │
# ╞════════════╪════════╪════════════╪═════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 2022102302 ┆ 2655   ┆ (1:54)     ┆ 3       ┆ … ┆ 0          ┆ Cover-3    ┆ Zone      ┆ 79        │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ J.Burrow   ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass…      ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022091809 ┆ 3698   ┆ (2:13)     ┆ 4       ┆ … ┆ 0          ┆ Quarters   ┆ Zone      ┆ 92        │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ J.Burrow   ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass…      ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022103004 ┆ 3146   ┆ (2:00)     ┆ 4       ┆ … ┆ 0          ┆ Quarters   ┆ Zone      ┆ 80        │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ D.Mills    ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pass …     ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022110610 ┆ 348    ┆ (9:28)     ┆ 1       ┆ … ┆ 0          ┆ Quarters   ┆ Zone      ┆ 23        │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ P.Mahomes  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ pas…       ┆         ┆   ┆            ┆            ┆           ┆           │
# │ 2022102700 ┆ 2799   ┆ (2:16)     ┆ 3       ┆ … ┆ 0          ┆ Cover-1    ┆ Man       ┆ 27        │
# │            ┆        ┆ (Shotgun)  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ L.Jackson  ┆         ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆ up …       ┆         ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────┴────────────┴─────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
tracking_df.head()
# Out:
# shape: (5, 18)
# ┌────────────┬────────┬───────┬────────────────┬───┬──────┬────────┬───────┬──────────────────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName    ┆ … ┆ dis  ┆ o      ┆ dir   ┆ event                │
# │ ---        ┆ ---    ┆ ---   ┆ ---            ┆   ┆ ---  ┆ ---    ┆ ---   ┆ ---                  │
# │ i64        ┆ i64    ┆ i64   ┆ str            ┆   ┆ f64  ┆ f64    ┆ f64   ┆ str                  │
# ╞════════════╪════════╪═══════╪════════════════╪═══╪══════╪════════╪═══════╪══════════════════════╡
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.07 ┆ 246.17 ┆ 68.34 ┆ huddle_break_offense │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.07 ┆ 245.41 ┆ 71.21 ┆ null                 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.07 ┆ 244.45 ┆ 69.9  ┆ null                 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.07 ┆ 244.45 ┆ 67.98 ┆ null                 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.07 ┆ 245.74 ┆ 62.83 ┆ null                 │
# └────────────┴────────┴───────┴────────────────┴───┴──────┴────────┴───────┴──────────────────────┘

# %%
def add_features_to_tracking_df(
    tracking_df: pl.DataFrame,
    players_df: pl.DataFrame,
    plays_df: pl.DataFrame,
) -> pl.DataFrame:
    """
    Consolidates play and player level data into the tracking data.

    Args:
        tracking_df (pl.DataFrame): Tracking data
        players_df (pl.DataFrame): Player data
        plays_df (pl.DataFrame): Play data

    Returns:
        pl.DataFrame: Tracking data with additional features.
    """
    # add `is_ball_carrier`, `team_indicator`, and other features to tracking data
    og_len = len(tracking_df)
    tracking_df = (
        tracking_df.join(
            plays_df.select(
                "gameId",
                "playId",
                "defensiveTeam"
            ),
            on=["gameId", "playId"],
            how="inner",
        )
        .join(
            players_df.select(["nflId", "displayName", "position"]).unique(), # select position column
            on=["nflId", "displayName"],
            how="left",
        )
        #.join(
        #    players_df.select(["nflId", "weight_Z", "height_Z"]).unique(),
        #    on="nflId",
        #    how="inner",
        #)
        .with_columns(
            isDefense=pl.when(pl.col("club") == pl.col("defensiveTeam"))
            .then(pl.lit(1))
            .otherwise(pl.lit(-1))
            .alias("isDefense"),
        )
        .drop(["defensiveTeam"])
        .drop(["event"])
    )

    assert len(tracking_df) == og_len, "Lost rows when joining tracking data with play/player data"

    return tracking_df

print("Add features to tracking")
tracking_df = add_features_to_tracking_df(tracking_df, players_df, plays_df)
del players_df
# Out:
# Add features to tracking

# %%
tracking_df.head()
# Out:
# shape: (5, 19)
# ┌────────────┬────────┬───────┬────────────────┬───┬────────┬───────┬──────────┬───────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName    ┆ … ┆ o      ┆ dir   ┆ position ┆ isDefense │
# │ ---        ┆ ---    ┆ ---   ┆ ---            ┆   ┆ ---    ┆ ---   ┆ ---      ┆ ---       │
# │ i64        ┆ i64    ┆ i64   ┆ str            ┆   ┆ f64    ┆ f64   ┆ str      ┆ i32       │
# ╞════════════╪════════╪═══════╪════════════════╪═══╪════════╪═══════╪══════════╪═══════════╡
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 246.17 ┆ 68.34 ┆ SS       ┆ 1         │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 245.41 ┆ 71.21 ┆ SS       ┆ 1         │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 244.45 ┆ 69.9  ┆ SS       ┆ 1         │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 244.45 ┆ 67.98 ┆ SS       ┆ 1         │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 245.74 ┆ 62.83 ┆ SS       ┆ 1         │
# └────────────┴────────┴───────┴────────────────┴───┴────────┴───────┴──────────┴───────────┘

# %%
def convert_tracking_to_cartesian(tracking_df: pl.DataFrame) -> pl.DataFrame:
    """
    Convert polar coordinates to Unit-circle Cartesian format.

    Args:
        tracking_df (pl.DataFrame): Tracking data

    Returns:
        pl.DataFrame: Tracking data with Cartesian coordinates.
    """
    return (
        tracking_df.with_columns(
            dir=((pl.col("dir") - 90) * -1) % 360,
            o=((pl.col("o") - 90) * -1) % 360,
        )
        # convert polar vectors to cartesian ((s, dir) -> (vx, vy), (o) -> (ox, oy))
        .with_columns(
            vx=pl.col("s") * pl.col("dir").radians().cos(),
            vy=pl.col("s") * pl.col("dir").radians().sin(),
            ox=pl.col("o").radians().cos(),
            oy=pl.col("o").radians().sin(),
        )
    )

print("Convert tracking to cartesian")
tracking_df = convert_tracking_to_cartesian(tracking_df)
# Out:
# Convert tracking to cartesian

# %%
tracking_df.head()
# Out:
# shape: (5, 23)
# ┌────────────┬────────┬───────┬────────────────┬───┬──────────┬──────────┬───────────┬───────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName    ┆ … ┆ vx       ┆ vy       ┆ ox        ┆ oy        │
# │ ---        ┆ ---    ┆ ---   ┆ ---            ┆   ┆ ---      ┆ ---      ┆ ---       ┆ ---       │
# │ i64        ┆ i64    ┆ i64   ┆ str            ┆   ┆ f64      ┆ f64      ┆ f64       ┆ f64       │
# ╞════════════╪════════╪═══════╪════════════════╪═══╪══════════╪══════════╪═══════════╪═══════════╡
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.669161 ┆ 0.265751 ┆ -0.914748 ┆ -0.404024 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.672161 ┆ 0.228691 ┆ -0.909309 ┆ -0.416122 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.647975 ┆ 0.237125 ┆ -0.902209 ┆ -0.431299 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.621126 ┆ 0.251203 ┆ -0.902209 ┆ -0.431299 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.578276 ┆ 0.296811 ┆ -0.91169  ┆ -0.410878 │
# └────────────┴────────┴───────┴────────────────┴───┴──────────┴──────────┴───────────┴───────────┘

# %% [markdown]
# NOTE: there two current `tracking` dataframes. One is the consolidated one, the other is augmented the direction of all players to assume that they are all moving in the same direction/

# %% [markdown]
# ## Explore model target --> Position of Masked player
#
# * Target dim.: (1, 2)
#   - first dim.: `displayName` of masked player
#   - second dim.: x-y coordinate of masked player on the field at the frame
#
# ## Goal: Randomly select a player and predict their x-y coordinates by removing them from the input sequence and having the model estimate their motion based on the locations of the 21 other players.

# %%
# Randomly select a player from players_in_game_play to filter out from each frame in the game and play

import random

def get_masked_players(tracking_df):
    """
    Randomly selects a player from a game and play, and filters their data from each frame.

    Args:
        tracking_df: The tracking DataFrame.

    Returns:
        tuple: A tuple containing the filtered tracking DataFrame and the masked players DataFrame.
    """
    masked_players_df = pl.DataFrame()

    for game_id, play_id in tracking_df.select(["gameId", "playId"]).unique().rows():

        # The defensive players in a given game + play
        filtered_df = tracking_df.filter(
          (pl.col("gameId") == game_id)
          & (pl.col("playId") == play_id)
          & (pl.col("frameId") == 1)
          & (pl.col("isDefense") == 1)
        )
        assert len(filtered_df) == 11, "No players found for gameId: {}, playId: {}".format(game_id, play_id)

        # Retrieve masked player
        selected_player = random.choice(filtered_df["displayName"].to_list())

        masked_player_df = tracking_df.filter(
            (pl.col("gameId") == game_id)
            & (pl.col("playId") == play_id)
            & (pl.col("displayName") == selected_player)
        )
        masked_players_df = pl.concat([masked_players_df, masked_player_df])

        # Filter out the selected player from tracking_df
        filtered_df = tracking_df.filter(
            ~(
                (pl.col("gameId") == game_id)
                & (pl.col("playId") == play_id)
                & (pl.col("displayName") == selected_player)
            )
        )
        #assert len(tracking_df) - len(masked_player_df) == len(filtered_df), "Players other than the masked player were lost"
        print(f"Player masked for gameId {game_id} playId {play_id}")

    return filtered_df, masked_player_df

# %%
print("Generate target - maskedPlayers")
rel_tracking_df, maskedPlayers_df = get_masked_players(tracking_df)
# Out:
# Generate target - maskedPlayers
# Player masked for gameId 2022091104 playId 1713
# Player masked for gameId 2022091107 playId 1841
# Player masked for gameId 2022091101 playId 1537
# Player masked for gameId 2022091103 playId 2955
# Player masked for gameId 2022091111 playId 1862
# Player masked for gameId 2022091106 playId 2429
# Player masked for gameId 2022091101 playId 2629
# Player masked for gameId 2022091108 playId 2962
# Player masked for gameId 2022091104 playId 4001
# Player masked for gameId 2022091112 playId 2723
# Player masked for gameId 2022091110 playId 1232
# Player masked for gameId 2022091200 playId 3826
# Player masked for gameId 2022091102 playId 3119
# Player masked for gameId 2022091101 playId 317
# Player masked for gameId 2022091110 playId 2845
# Player masked for gameId 2022091106 playId 380
# Player masked for gameId 2022091107 playId 1779
# Player masked for gameId 2022091104 playId 865
# Player masked for gameId 2022091111 playId 542
# Player masked for gameId 2022091112 playId 3672
# Player masked for gameId 2022091104 playId 580
# Player masked for gameId 2022091107 playId 2406
# Player masked for gameId 2022091101 playId 3569
# Player masked for gameId 2022091110 playId 240
# Player masked for gameId 2022091110 playId 799
# Player masked for gameId 2022091113 playId 3947
# Player masked for gameId 2022091111 playId 475
# Player masked for gameId 2022091105 playId 3995
# Player masked for gameId 2022091113 playId 3173
# Player masked for gameId 2022091107 playId 3933
# Player masked for gameId 2022091113 playId 224
# Player masked for gameId 2022091100 playId 4210
# Player masked for gameId 2022091104 playId 2995
# Player masked for gameId 2022090800 playId 3696
# Player masked for gameId 2022091106 playId 1945
# Player masked for gameId 2022091111 playId 1706
# Player masked for gameId 2022091102 playId 1493
# Player masked for gameId 2022091200 playId 3194
# Player masked for gameId 2022091101 playId 3961
# Player masked for gameId 2022091101 playId 3006
# Player masked for gameId 2022091104 playId 3956
# Player masked for gameId 2022091100 playId 4307
# Player masked for gameId 2022091108 playId 2983
# Player masked for gameId 2022091107 playId 1120
# Player masked for gameId 2022091113 playId 966
# Player masked for gameId 2022091102 playId 64
# Player masked for gameId 2022091112 playId 112
# Player masked for gameId 2022091113 playId 1929
# Player masked for gameId 2022091102 playId 3921
# Player masked for gameId 2022091108 playId 1995
# Player masked for gameId 2022091100 playId 1815
# Player masked for gameId 2022091200 playId 1299
# Player masked for gameId 2022091105 playId 4655
# Player masked for gameId 2022091102 playId 4166
# Player masked for gameId 2022091101 playId 620
# Player masked for gameId 2022091100 playId 2512
# Player masked for gameId 2022091112 playId 2475
# Player masked for gameId 2022090800 playId 1800
# Player masked for gameId 2022091105 playId 548
# Player masked for gameId 2022091100 playId 935
# Player masked for gameId 2022090800 playId 2208
# Player masked for gameId 2022091200 playId 3149
# Player masked for gameId 2022090800 playId 818
# Player masked for gameId 2022091111 playId 2236
# Player masked for gameId 2022091105 playId 2718
# Player masked for gameId 2022091110 playId 3399
# Player masked for gameId 2022091105 playId 315
# Player masked for gameId 2022091109 playId 2776
# Player masked for gameId 2022091113 playId 2983
# Player masked for gameId 2022091104 playId 3596
# Player masked for gameId 2022091104 playId 2781
# Player masked for gameId 2022091110 playId 195
# Player masked for gameId 2022091100 playId 501
# Player masked for gameId 2022091106 playId 1798
# Player masked for gameId 2022091107 playId 4047
# Player masked for gameId 2022091104 playId 4121
# Player masked for gameId 2022091110 playId 1868
# Player masked for gameId 2022091103 playId 541
# Player masked for gameId 2022091100 playId 1928
# Player masked for gameId 2022090800 playId 2599
# Player masked for gameId 2022091112 playId 611
# Player masked for gameId 2022091101 playId 4104
# Player masked for gameId 2022091108 playId 392
# Player masked for gameId 2022091110 playId 2531
# Player masked for gameId 2022091104 playId 3391
# Player masked for gameId 2022091102 playId 2238
# Player masked for gameId 2022091112 playId 3696
# Player masked for gameId 2022091107 playId 3742
# Player masked for gameId 2022090800 playId 2815
# Player masked for gameId 2022091104 playId 3754
# Player masked for gameId 2022091103 playId 412
# Player masked for gameId 2022091100 playId 2332
# Player masked for gameId 2022091200 playId 810
# Player masked for gameId 2022091110 playId 3357
# Player masked for gameId 2022091101 playId 2683
# Player masked for gameId 2022091102 playId 552
# Player masked for gameId 2022091108 playId 2398
# Player masked for gameId 2022091109 playId 3597
# Player masked for gameId 2022091101 playId 2951
# Player masked for gameId 2022091102 playId 2945
# Player masked for gameId 2022091109 playId 2824
# Player masked for gameId 2022091102 playId 3652
# Player masked for gameId 2022091200 playId 2522
# Player masked for gameId 2022090800 playId 550
# Player masked for gameId 2022091112 playId 3416
# Player masked for gameId 2022090800 playId 1126
# Player masked for gameId 2022091106 playId 3002
# Player masked for gameId 2022091110 playId 3797
# Player masked for gameId 2022091111 playId 770
# Player masked for gameId 2022091108 playId 1874
# Player masked for gameId 2022091103 playId 4993
# Player masked for gameId 2022091105 playId 1236
# Player masked for gameId 2022091200 playId 2801
# Player masked for gameId 2022091109 playId 3208
# Player masked for gameId 2022091102 playId 2532
# Player masked for gameId 2022090800 playId 1315
# Player masked for gameId 2022091103 playId 1947
# Player masked for gameId 2022091110 playId 2609
# Player masked for gameId 2022091108 playId 2914
# Player masked for gameId 2022091111 playId 1819
# Player masked for gameId 2022091113 playId 1415
# Player masked for gameId 2022091107 playId 412
# Player masked for gameId 2022091101 playId 1122
# Player masked for gameId 2022091111 playId 1840
# Player masked for gameId 2022091108 playId 1222
# Player masked for gameId 2022091111 playId 3479
# Player masked for gameId 2022091110 playId 3092
# Player masked for gameId 2022091103 playId 902
# Player masked for gameId 2022091101 playId 1144
# Player masked for gameId 2022090800 playId 3047
# Player masked for gameId 2022091110 playId 1203
# Player masked for gameId 2022091111 playId 1925
# Player masked for gameId 2022091109 playId 3938
# Player masked for gameId 2022091200 playId 688
# Player masked for gameId 2022091100 playId 1017
# Player masked for gameId 2022091101 playId 85
# Player masked for gameId 2022091200 playId 3404
# Player masked for gameId 2022091105 playId 3812
# Player masked for gameId 2022091111 playId 1567
# Player masked for gameId 2022091113 playId 1318
# Player masked for gameId 2022091102 playId 2837
# Player masked for gameId 2022091105 playId 912
# Player masked for gameId 2022091113 playId 2424
# Player masked for gameId 2022091104 playId 1228
# Player masked for gameId 2022091109 playId 2083
# Player masked for gameId 2022091103 playId 1126
# Player masked for gameId 2022091108 playId 3396
# Player masked for gameId 2022091112 playId 1674
# Player masked for gameId 2022091109 playId 3962
# Player masked for gameId 2022091109 playId 229
# Player masked for gameId 2022091107 playId 2987
# Player masked for gameId 2022091103 playId 4199
# Player masked for gameId 2022091109 playId 483
# Player masked for gameId 2022091102 playId 3859
# Player masked for gameId 2022091103 playId 3367
# Player masked for gameId 2022091102 playId 1562
# Player masked for gameId 2022091200 playId 3048
# Player masked for gameId 2022091100 playId 594
# Player masked for gameId 2022091107 playId 301
# Player masked for gameId 2022091100 playId 2841
# Player masked for gameId 2022091113 playId 2542
# Player masked for gameId 2022091109 playId 4512
# Player masked for gameId 2022091105 playId 643
# Player masked for gameId 2022091111 playId 1999
# Player masked for gameId 2022091102 playId 4080
# Player masked for gameId 2022091110 playId 2677
# Player masked for gameId 2022091102 playId 1286
# Player masked for gameId 2022091103 playId 4947
# Player masked for gameId 2022090800 playId 593
# Player masked for gameId 2022091106 playId 633
# Player masked for gameId 2022091102 playId 1363
# Player masked for gameId 2022091111 playId 121
# Player masked for gameId 2022091101 playId 1901
# Player masked for gameId 2022091100 playId 3050
# Player masked for gameId 2022090800 playId 3190
# Player masked for gameId 2022091104 playId 1380
# Player masked for gameId 2022091104 playId 2109
# Player masked for gameId 2022091100 playId 99
# Player masked for gameId 2022091100 playId 233
# Player masked for gameId 2022091108 playId 3599
# Player masked for gameId 2022091104 playId 689
# Player masked for gameId 2022091104 playId 1207
# Player masked for gameId 2022091100 playId 1552
# Player masked for gameId 2022091103 playId 1171
# Player masked for gameId 2022090800 playId 167
# Player masked for gameId 2022091112 playId 3200
# Player masked for gameId 2022091105 playId 379
# Player masked for gameId 2022091105 playId 4232
# Player masked for gameId 2022091200 playId 3596
# Player masked for gameId 2022091106 playId 1446
# Player masked for gameId 2022091200 playId 1704
# Player masked for gameId 2022091101 playId 2545
# Player masked for gameId 2022091200 playId 3001
# Player masked for gameId 2022091106 playId 752
# Player masked for gameId 2022091112 playId 800
# Player masked for gameId 2022091103 playId 4154
# Player masked for gameId 2022091111 playId 430
# Player masked for gameId 2022090800 playId 2400
# Player masked for gameId 2022091111 playId 142
# Player masked for gameId 2022091113 playId 1566
# Player masked for gameId 2022091107 playId 3503
# Player masked for gameId 2022091101 playId 1357
# Player masked for gameId 2022091111 playId 2278
# Player masked for gameId 2022091110 playId 4056
# Player masked for gameId 2022091106 playId 2261
# Player masked for gameId 2022091112 playId 1539
# Player masked for gameId 2022091105 playId 1996
# Player masked for gameId 2022091111 playId 2583
# Player masked for gameId 2022091103 playId 4540
# Player masked for gameId 2022091102 playId 2511
# Player masked for gameId 2022091102 playId 1472
# Player masked for gameId 2022091107 playId 2803
# Player masked for gameId 2022091103 playId 1336
# Player masked for gameId 2022091107 playId 1696
# Player masked for gameId 2022091108 playId 2027
# Player masked for gameId 2022091104 playId 1020
# Player masked for gameId 2022091103 playId 520
# Player masked for gameId 2022090800 playId 2137
# Player masked for gameId 2022091101 playId 361
# Player masked for gameId 2022091101 playId 1166
# Player masked for gameId 2022091100 playId 1191
# Player masked for gameId 2022091109 playId 1997
# Player masked for gameId 2022091109 playId 3986
# Player masked for gameId 2022091111 playId 878
# Player masked for gameId 2022091101 playId 2832
# Player masked for gameId 2022091110 playId 3423
# Player masked for gameId 2022091105 playId 595
# Player masked for gameId 2022091105 playId 3163
# Player masked for gameId 2022091110 playId 3140
# Player masked for gameId 2022091200 playId 3553
# Player masked for gameId 2022091106 playId 2680
# Player masked for gameId 2022091105 playId 2697
# Player masked for gameId 2022091113 playId 3284
# Player masked for gameId 2022091113 playId 3385
# Player masked for gameId 2022091112 playId 1884
# Player masked for gameId 2022091107 playId 2070
# Player masked for gameId 2022091113 playId 489
# Player masked for gameId 2022091100 playId 2555
# Player masked for gameId 2022091102 playId 2717
# Player masked for gameId 2022091112 playId 422
# Player masked for gameId 2022091105 playId 4731
# Player masked for gameId 2022091111 playId 839
# Player masked for gameId 2022091109 playId 4409
# Player masked for gameId 2022091102 playId 3673
# Player masked for gameId 2022091108 playId 1309
# Player masked for gameId 2022091104 playId 1917
# Player masked for gameId 2022091101 playId 1945
# Player masked for gameId 2022091111 playId 2065
# Player masked for gameId 2022091101 playId 3897
# Player masked for gameId 2022091103 playId 1429
# Player masked for gameId 2022091102 playId 1726
# Player masked for gameId 2022091101 playId 3336
# Player masked for gameId 2022091110 playId 3270
# Player masked for gameId 2022091103 playId 2103
# Player masked for gameId 2022091104 playId 713
# Player masked for gameId 2022091107 playId 2285
# Player masked for gameId 2022091104 playId 1436
# Player masked for gameId 2022091103 playId 3505
# Player masked for gameId 2022091103 playId 1363
# Player masked for gameId 2022091103 playId 2357
# Player masked for gameId 2022091112 playId 3128
# Player masked for gameId 2022091105 playId 2174
# Player masked for gameId 2022091112 playId 1236
# Player masked for gameId 2022091200 playId 2188
# Player masked for gameId 2022091111 playId 2946
# Player masked for gameId 2022091109 playId 4075
# Player masked for gameId 2022091105 playId 273
# Player masked for gameId 2022091104 playId 3899
# Player masked for gameId 2022091102 playId 189
# Player masked for gameId 2022091102 playId 1700
# Player masked for gameId 2022091101 playId 1826
# Player masked for gameId 2022091112 playId 3310
# Player masked for gameId 2022091101 playId 3263
# Player masked for gameId 2022091111 playId 451
# Player masked for gameId 2022090800 playId 1657
# Player masked for gameId 2022091113 playId 3642
# Player masked for gameId 2022091110 playId 269
# Player masked for gameId 2022091109 playId 1041
# Player masked for gameId 2022091200 playId 2479
# Player masked for gameId 2022091113 playId 2009
# Player masked for gameId 2022091113 playId 2377
# Player masked for gameId 2022091112 playId 157
# Player masked for gameId 2022091107 playId 1803
# Player masked for gameId 2022091104 playId 3434
# Player masked for gameId 2022090800 playId 2093
# Player masked for gameId 2022091103 playId 1565
# Player masked for gameId 2022091103 playId 3032
# Player masked for gameId 2022091102 playId 3381
# Player masked for gameId 2022091110 playId 3599
# Player masked for gameId 2022091108 playId 296
# Player masked for gameId 2022091111 playId 3404
# Player masked for gameId 2022091110 playId 2000
# Player masked for gameId 2022091106 playId 1709
# Player masked for gameId 2022091200 playId 3747
# Player masked for gameId 2022090800 playId 1406
# Player masked for gameId 2022091104 playId 2130
# Player masked for gameId 2022091112 playId 917
# Player masked for gameId 2022091113 playId 1389
# Player masked for gameId 2022091108 playId 882
# Player masked for gameId 2022091112 playId 2167
# Player masked for gameId 2022091109 playId 383
# Player masked for gameId 2022091100 playId 1413
# Player masked for gameId 2022091109 playId 3678
# Player masked for gameId 2022091100 playId 762
# Player masked for gameId 2022091112 playId 2864
# Player masked for gameId 2022091108 playId 3502
# Player masked for gameId 2022091103 playId 2670
# Player masked for gameId 2022091112 playId 1382
# Player masked for gameId 2022091109 playId 3752
# Player masked for gameId 2022091200 playId 446
# Player masked for gameId 2022091108 playId 1089
# Player masked for gameId 2022091113 playId 3684
# Player masked for gameId 2022091109 playId 767
# Player masked for gameId 2022091106 playId 3550
# Player masked for gameId 2022091101 playId 2199
# Player masked for gameId 2022091105 playId 688
# Player masked for gameId 2022091200 playId 109
# Player masked for gameId 2022091106 playId 1380
# Player masked for gameId 2022091105 playId 865
# Player masked for gameId 2022091200 playId 2944
# Player masked for gameId 2022091113 playId 1436
# Player masked for gameId 2022091109 playId 4596
# Player masked for gameId 2022091107 playId 1144
# Player masked for gameId 2022091101 playId 1720
# Player masked for gameId 2022091102 playId 756
# Player masked for gameId 2022091108 playId 2867
# Player masked for gameId 2022091106 playId 2450
# Player masked for gameId 2022091111 playId 3319
# Player masked for gameId 2022091105 playId 841
# Player masked for gameId 2022091111 playId 3171
# Player masked for gameId 2022091112 playId 3176
# Player masked for gameId 2022091111 playId 730
# Player masked for gameId 2022091110 playId 3674
# Player masked for gameId 2022091112 playId 736
# Player masked for gameId 2022091111 playId 2988
# Player masked for gameId 2022091105 playId 984
# Player masked for gameId 2022091103 playId 2037
# Player masked for gameId 2022091100 playId 914
# Player masked for gameId 2022091102 playId 3502
# Player masked for gameId 2022091112 playId 2840
# Player masked for gameId 2022091103 playId 1150
# Player masked for gameId 2022091101 playId 2298
# Player masked for gameId 2022091104 playId 288
# Player masked for gameId 2022091105 playId 4438
# Player masked for gameId 2022090800 playId 1967
# Player masked for gameId 2022091105 playId 732
# Player masked for gameId 2022091107 playId 3718
# Player masked for gameId 2022091104 playId 4075
# Player masked for gameId 2022091105 playId 1330
# Player masked for gameId 2022091109 playId 1266
# Player masked for gameId 2022090800 playId 2551
# Player masked for gameId 2022091103 playId 1672
# Player masked for gameId 2022090800 playId 692
# Player masked for gameId 2022091101 playId 3287
# Player masked for gameId 2022091100 playId 996
# Player masked for gameId 2022091104 playId 462
# Player masked for gameId 2022091109 playId 1592
# Player masked for gameId 2022091112 playId 181
# Player masked for gameId 2022091200 playId 716
# Player masked for gameId 2022091200 playId 315
# Player masked for gameId 2022091106 playId 442
# Player masked for gameId 2022091111 playId 2020
# Player masked for gameId 2022091107 playId 3374
# Player masked for gameId 2022091113 playId 1059
# Player masked for gameId 2022091103 playId 499
# Player masked for gameId 2022091107 playId 3253
# Player masked for gameId 2022091112 playId 1613
# Player masked for gameId 2022091111 playId 2044
# Player masked for gameId 2022091110 playId 1908
# Player masked for gameId 2022091109 playId 2425
# Player masked for gameId 2022091103 playId 2201
# Player masked for gameId 2022091100 playId 1793
# Player masked for gameId 2022091104 playId 2007
# Player masked for gameId 2022091113 playId 3139
# Player masked for gameId 2022091108 playId 2799
# Player masked for gameId 2022091104 playId 4469
# Player masked for gameId 2022091103 playId 2058
# Player masked for gameId 2022091110 playId 123
# Player masked for gameId 2022091106 playId 2767
# Player masked for gameId 2022091105 playId 1742
# Player masked for gameId 2022090800 playId 529
# Player masked for gameId 2022091101 playId 3040
# Player masked for gameId 2022091103 playId 2907
# Player masked for gameId 2022091109 playId 3523
# Player masked for gameId 2022091107 playId 2866
# Player masked for gameId 2022091105 playId 2425
# Player masked for gameId 2022091109 playId 2481
# Player masked for gameId 2022091102 playId 1162
# Player masked for gameId 2022091111 playId 1237
# Player masked for gameId 2022091101 playId 4242
# Player masked for gameId 2022090800 playId 414
# Player masked for gameId 2022091112 playId 3361
# Player masked for gameId 2022091105 playId 4416
# Player masked for gameId 2022091109 playId 3909
# Player masked for gameId 2022091112 playId 2907
# Player masked for gameId 2022091109 playId 2635
# Player masked for gameId 2022091110 playId 942
# Player masked for gameId 2022091100 playId 4266
# Player masked for gameId 2022091107 playId 1194
# Player masked for gameId 2022091110 playId 3492
# Player masked for gameId 2022091112 playId 3224
# Player masked for gameId 2022091200 playId 2923
# Player masked for gameId 2022091104 playId 2190
# Player masked for gameId 2022091113 playId 3807
# Player masked for gameId 2022091102 playId 821
# Player masked for gameId 2022091113 playId 413
# Player masked for gameId 2022091108 playId 3105
# Player masked for gameId 2022091110 playId 3652
# Player masked for gameId 2022091109 playId 1475
# Player masked for gameId 2022091105 playId 4462
# Player masked for gameId 2022091103 playId 2829
# Player masked for gameId 2022091107 playId 3115
# Player masked for gameId 2022091101 playId 641
# Player masked for gameId 2022091103 playId 926
# Player masked for gameId 2022091111 playId 2299
# Player masked for gameId 2022091112 playId 1406
# Player masked for gameId 2022091112 playId 1165
# Player masked for gameId 2022091107 playId 202
# Player masked for gameId 2022091111 playId 2212
# Player masked for gameId 2022091200 playId 1521
# Player masked for gameId 2022091112 playId 3766
# Player masked for gameId 2022091102 playId 1928
# Player masked for gameId 2022091102 playId 2331
# Player masked for gameId 2022091102 playId 488
# Player masked for gameId 2022091101 playId 2365
# Player masked for gameId 2022091108 playId 2377
# Player masked for gameId 2022091110 playId 1649
# Player masked for gameId 2022091100 playId 1231
# Player masked for gameId 2022091101 playId 3101
# Player masked for gameId 2022091107 playId 3789
# Player masked for gameId 2022091105 playId 3461
# Player masked for gameId 2022091112 playId 1479
# Player masked for gameId 2022091112 playId 3551
# Player masked for gameId 2022091105 playId 403
# Player masked for gameId 2022091106 playId 2605
# Player masked for gameId 2022091107 playId 4200
# Player masked for gameId 2022091104 playId 1528
# Player masked for gameId 2022091104 playId 3369
# Player masked for gameId 2022091103 playId 364
# Player masked for gameId 2022091109 playId 1120
# Player masked for gameId 2022091105 playId 2637
# Player masked for gameId 2022091105 playId 4794
# Player masked for gameId 2022090800 playId 1358
# Player masked for gameId 2022091109 playId 1864
# Player masked for gameId 2022091109 playId 4387
# Player masked for gameId 2022091113 playId 2743
# Player masked for gameId 2022091106 playId 3475
# Player masked for gameId 2022091200 playId 64
# Player masked for gameId 2022091102 playId 3360
# Player masked for gameId 2022091111 playId 280
# Player masked for gameId 2022091112 playId 62
# Player masked for gameId 2022091112 playId 862
# Player masked for gameId 2022091100 playId 3778
# Player masked for gameId 2022091102 playId 3739
# Player masked for gameId 2022091108 playId 216
# Player masked for gameId 2022091110 playId 4030
# Player masked for gameId 2022090800 playId 1736
# Player masked for gameId 2022091109 playId 3229
# Player masked for gameId 2022091103 playId 3251
# Player masked for gameId 2022091112 playId 379
# Player masked for gameId 2022091110 playId 1539
# Player masked for gameId 2022091107 playId 2891
# Player masked for gameId 2022091105 playId 1114
# Player masked for gameId 2022091104 playId 803
# Player masked for gameId 2022091103 playId 1648
# Player masked for gameId 2022091107 playId 3163
# Player masked for gameId 2022091106 playId 2978
# Player masked for gameId 2022091103 playId 5039
# Player masked for gameId 2022091113 playId 2201
# Player masked for gameId 2022091100 playId 4032
# Player masked for gameId 2022091102 playId 1992
# Player masked for gameId 2022091101 playId 3315
# Player masked for gameId 2022091104 playId 777
# Player masked for gameId 2022091101 playId 1192
# Player masked for gameId 2022091106 playId 83
# Player masked for gameId 2022091106 playId 2170
# Player masked for gameId 2022091113 playId 2262
# Player masked for gameId 2022091107 playId 723
# Player masked for gameId 2022091111 playId 3683
# Player masked for gameId 2022091111 playId 2360
# Player masked for gameId 2022090800 playId 2884
# Player masked for gameId 2022091110 playId 2786
# Player masked for gameId 2022091111 playId 2113
# Player masked for gameId 2022091107 playId 768
# Player masked for gameId 2022091106 playId 338
# Player masked for gameId 2022091200 playId 180
# Player masked for gameId 2022091112 playId 2015
# Player masked for gameId 2022091107 playId 2712
# Player masked for gameId 2022091102 playId 3096
# Player masked for gameId 2022091101 playId 748
# Player masked for gameId 2022091106 playId 3361
# Player masked for gameId 2022091107 playId 846
# Player masked for gameId 2022091110 playId 593
# Player masked for gameId 2022091104 playId 58
# Player masked for gameId 2022091100 playId 1281
# Player masked for gameId 2022091112 playId 3492
# Player masked for gameId 2022091106 playId 1653
# Player masked for gameId 2022091101 playId 3591
# Player masked for gameId 2022091107 playId 595
# Player masked for gameId 2022091112 playId 3246
# Player masked for gameId 2022091104 playId 128
# Player masked for gameId 2022091110 playId 1394
# Player masked for gameId 2022091109 playId 3253
# Player masked for gameId 2022091109 playId 3568
# Player masked for gameId 2022091107 playId 3864
# Player masked for gameId 2022091102 playId 1954
# Player masked for gameId 2022091109 playId 2941
# Player masked for gameId 2022091102 playId 364
# Player masked for gameId 2022091111 playId 609
# Player masked for gameId 2022091111 playId 2681
# Player masked for gameId 2022091105 playId 2476
# Player masked for gameId 2022090800 playId 3283
# Player masked for gameId 2022091107 playId 2791
# Player masked for gameId 2022091103 playId 2511
# Player masked for gameId 2022091113 playId 1146
# Player masked for gameId 2022091101 playId 63
# Player masked for gameId 2022091107 playId 1469
# Player masked for gameId 2022091101 playId 3841
# Player masked for gameId 2022091200 playId 2712
# Player masked for gameId 2022091110 playId 3002
# Player masked for gameId 2022091103 playId 2222
# Player masked for gameId 2022091109 playId 3357
# Player masked for gameId 2022091113 playId 179
# Player masked for gameId 2022091110 playId 2022
# Player masked for gameId 2022091103 playId 3126
# Player masked for gameId 2022091107 playId 2478
# Player masked for gameId 2022091112 playId 1946
# Player masked for gameId 2022091110 playId 870
# Player masked for gameId 2022091100 playId 3816
# Player masked for gameId 2022091108 playId 3523
# Player masked for gameId 2022091105 playId 3670
# Player masked for gameId 2022091101 playId 3454
# Player masked for gameId 2022091100 playId 3148
# Player masked for gameId 2022091101 playId 3378
# Player masked for gameId 2022091103 playId 3945
# Player masked for gameId 2022091113 playId 3894
# Player masked for gameId 2022091110 playId 2380
# Player masked for gameId 2022091100 playId 3526
# Player masked for gameId 2022091113 playId 2954
# Player masked for gameId 2022091108 playId 3177
# Player masked for gameId 2022091111 playId 2321
# Player masked for gameId 2022091111 playId 3357
# Player masked for gameId 2022091101 playId 184
# Player masked for gameId 2022091200 playId 1793
# Player masked for gameId 2022091200 playId 286
# Player masked for gameId 2022091105 playId 3911
# Player masked for gameId 2022091113 playId 267
# Player masked for gameId 2022091110 playId 968
# Player masked for gameId 2022091101 playId 3125
# Player masked for gameId 2022091102 playId 107
# Player masked for gameId 2022091110 playId 3331
# Player masked for gameId 2022091104 playId 1041
# Player masked for gameId 2022091102 playId 3523
# Player masked for gameId 2022091106 playId 1544
# Player masked for gameId 2022091109 playId 3156
# Player masked for gameId 2022091102 playId 3043
# Player masked for gameId 2022091107 playId 469
# Player masked for gameId 2022091105 playId 3139
# Player masked for gameId 2022091111 playId 3433
# Player masked for gameId 2022091104 playId 2269
# Player masked for gameId 2022091106 playId 2116
# Player masked for gameId 2022091100 playId 3671
# Player masked for gameId 2022090800 playId 56
# Player masked for gameId 2022091105 playId 2616
# Player masked for gameId 2022091103 playId 2272
# Player masked for gameId 2022091104 playId 953
# Player masked for gameId 2022091111 playId 2725
# Player masked for gameId 2022091109 playId 1968
# Player masked for gameId 2022091102 playId 2596
# Player masked for gameId 2022091105 playId 667
# Player masked for gameId 2022091113 playId 1457
# Player masked for gameId 2022091109 playId 677
# Player masked for gameId 2022091100 playId 4068
# Player masked for gameId 2022091104 playId 3122
# Player masked for gameId 2022091109 playId 1944
# Player masked for gameId 2022091200 playId 565
# Player masked for gameId 2022090800 playId 867
# Player masked for gameId 2022091111 playId 2806
# Player masked for gameId 2022091100 playId 78
# Player masked for gameId 2022090800 playId 3489
# Player masked for gameId 2022091108 playId 2140
# Player masked for gameId 2022091110 playId 3185
# Player masked for gameId 2022091107 playId 230
# Player masked for gameId 2022091102 playId 1588
# Player masked for gameId 2022091107 playId 1165
# Player masked for gameId 2022091105 playId 4533
# Player masked for gameId 2022091108 playId 1483
# Player masked for gameId 2022091105 playId 4578
# Player masked for gameId 2022091200 playId 2965
# Player masked for gameId 2022091108 playId 1948
# Player masked for gameId 2022091108 playId 2098
# Player masked for gameId 2022091104 playId 3502
# Player masked for gameId 2022091101 playId 1014
# Player masked for gameId 2022091100 playId 2741
# Player masked for gameId 2022090800 playId 646
# Player masked for gameId 2022090800 playId 2908
# Player masked for gameId 2022091109 playId 3797
# Player masked for gameId 2022091111 playId 2089
# Player masked for gameId 2022091200 playId 2667
# Player masked for gameId 2022091104 playId 2537
# Player masked for gameId 2022091106 playId 1125
# Player masked for gameId 2022091101 playId 3146
# Player masked for gameId 2022091108 playId 2846
# Player masked for gameId 2022091100 playId 2159
# Player masked for gameId 2022091100 playId 2204
# Player masked for gameId 2022091108 playId 3803
# Player masked for gameId 2022090800 playId 1836
# Player masked for gameId 2022091105 playId 101
# Player masked for gameId 2022091106 playId 3337
# Player masked for gameId 2022091103 playId 3294
# Player masked for gameId 2022091108 playId 1778
# Player masked for gameId 2022091108 playId 2321
# Player masked for gameId 2022091113 playId 1363
# Player masked for gameId 2022091109 playId 2726
# Player masked for gameId 2022090800 playId 3636
# Player masked for gameId 2022091100 playId 301
# Player masked for gameId 2022091103 playId 1493
# Player masked for gameId 2022091103 playId 4921
# Player masked for gameId 2022091104 playId 3037
# Player masked for gameId 2022091104 playId 4197
# Player masked for gameId 2022091105 playId 249
# Player masked for gameId 2022091108 playId 633
# Player masked for gameId 2022091200 playId 3077
# Player masked for gameId 2022091110 playId 3026
# Player masked for gameId 2022091107 playId 744
# Player masked for gameId 2022091112 playId 2981
# Player masked for gameId 2022091113 playId 2283
# Player masked for gameId 2022091110 playId 3471
# Player masked for gameId 2022091106 playId 2721
# Player masked for gameId 2022091104 playId 2974
# Player masked for gameId 2022091103 playId 995
# Player masked for gameId 2022091110 playId 2448
# Player masked for gameId 2022091110 playId 2063
# Player masked for gameId 2022091103 playId 1700
# Player masked for gameId 2022091100 playId 212
# Player masked for gameId 2022091105 playId 772
# Player masked for gameId 2022091113 playId 334
# Player masked for gameId 2022091102 playId 2804
# Player masked for gameId 2022091100 playId 2491
# Player masked for gameId 2022091100 playId 4131
# Player masked for gameId 2022091104 playId 2447
# Player masked for gameId 2022090800 playId 486
# Player masked for gameId 2022091106 playId 2237
# Player masked for gameId 2022090800 playId 2860
# Player masked for gameId 2022091200 playId 1409
# Player masked for gameId 2022091107 playId 3647
# Player masked for gameId 2022091109 playId 4443
# Player masked for gameId 2022091107 playId 1618
# Player masked for gameId 2022091106 playId 2864
# Player masked for gameId 2022090800 playId 299
# Player masked for gameId 2022090800 playId 2381
# Player masked for gameId 2022091107 playId 2243
# Player masked for gameId 2022091100 playId 3446
# Player masked for gameId 2022091108 playId 1461
# Player masked for gameId 2022091104 playId 1847
# Player masked for gameId 2022091200 playId 2688
# Player masked for gameId 2022091102 playId 3148
# Player masked for gameId 2022091109 playId 611
# Player masked for gameId 2022091111 playId 3075
# Player masked for gameId 2022091110 playId 1959
# Player masked for gameId 2022091107 playId 136
# Player masked for gameId 2022091108 playId 3947
# Player masked for gameId 2022091101 playId 2478
# Player masked for gameId 2022090800 playId 2184
# Player masked for gameId 2022091112 playId 1123
# Player masked for gameId 2022091103 playId 3389
# Player masked for gameId 2022091108 playId 1060
# Player masked for gameId 2022091101 playId 2431
# Player masked for gameId 2022091110 playId 1821
# Player masked for gameId 2022091101 playId 1980
# Player masked for gameId 2022091112 playId 2757
# Player masked for gameId 2022091111 playId 401
# Player masked for gameId 2022091109 playId 251
# Player masked for gameId 2022091108 playId 2353
# Player masked for gameId 2022091100 playId 741
# Player masked for gameId 2022091113 playId 3035
# Player masked for gameId 2022091200 playId 3491
# Player masked for gameId 2022091200 playId 467
# Player masked for gameId 2022091106 playId 607
# Player masked for gameId 2022091110 playId 347
# Player masked for gameId 2022091100 playId 572
# Player masked for gameId 2022091104 playId 2228
# Player masked for gameId 2022091101 playId 3923
# Player masked for gameId 2022091106 playId 2743
# Player masked for gameId 2022091200 playId 3515
# Player masked for gameId 2022091108 playId 729
# Player masked for gameId 2022091106 playId 1966
# Player masked for gameId 2022090800 playId 101
# Player masked for gameId 2022090800 playId 775
# Player masked for gameId 2022090800 playId 3121
# Player masked for gameId 2022090800 playId 2979
# Player masked for gameId 2022091110 playId 649
# Player masked for gameId 2022091110 playId 3209
# Player masked for gameId 2022091108 playId 1246
# Player masked for gameId 2022091101 playId 2783
# Player masked for gameId 2022091109 playId 656
# Player masked for gameId 2022091109 playId 1636
# Player masked for gameId 2022091200 playId 2391
# Player masked for gameId 2022091113 playId 4016
# Player masked for gameId 2022091100 playId 956
# Player masked for gameId 2022091112 playId 3072
# Player masked for gameId 2022090800 playId 2043
# Player masked for gameId 2022091106 playId 1098
# Player masked for gameId 2022091105 playId 3649
# Player masked for gameId 2022091105 playId 1542
# Player masked for gameId 2022091103 playId 4008
# Player masked for gameId 2022090800 playId 1254
# Player masked for gameId 2022090800 playId 3092
# Player masked for gameId 2022091111 playId 973
# Player masked for gameId 2022091104 playId 2952
# Player masked for gameId 2022091111 playId 3051
# Player masked for gameId 2022091108 playId 1552
# Player masked for gameId 2022091111 playId 1192
# Player masked for gameId 2022091200 playId 375
# Player masked for gameId 2022091106 playId 1568
# Player masked for gameId 2022090800 playId 617
# Player masked for gameId 2022091108 playId 3417
# Player masked for gameId 2022091111 playId 1416
# Player masked for gameId 2022090800 playId 2360
# Player masked for gameId 2022091107 playId 3527
# Player masked for gameId 2022091103 playId 852
# Player masked for gameId 2022091100 playId 3310
# Player masked for gameId 2022091104 playId 4176
# Player masked for gameId 2022091101 playId 3221
# Player masked for gameId 2022091100 playId 1713
# Player masked for gameId 2022091108 playId 515
# Player masked for gameId 2022091200 playId 3216
# Player masked for gameId 2022091105 playId 2887
# Player masked for gameId 2022091105 playId 818
# Player masked for gameId 2022091109 playId 888
# Player masked for gameId 2022091112 playId 3744
# Player masked for gameId 2022091110 playId 3983
# Player masked for gameId 2022091104 playId 238
# Player masked for gameId 2022091103 playId 2243
# Player masked for gameId 2022091200 playId 1851
# Player masked for gameId 2022091103 playId 690
# Player masked for gameId 2022091100 playId 3119
# Player masked for gameId 2022091200 playId 1680
# Player masked for gameId 2022091105 playId 4394
# Player masked for gameId 2022091106 playId 196
# Player masked for gameId 2022091103 playId 796
# Player masked for gameId 2022091113 playId 3211
# Player masked for gameId 2022091113 playId 2470
# Player masked for gameId 2022091109 playId 587
# Player masked for gameId 2022091100 playId 57
# Player masked for gameId 2022091111 playId 1006
# Player masked for gameId 2022091113 playId 1609
# Player masked for gameId 2022090800 playId 1483
# Player masked for gameId 2022091200 playId 931
# Player masked for gameId 2022091109 playId 1772
# Player masked for gameId 2022091103 playId 743
# Player masked for gameId 2022091108 playId 3153
# Player masked for gameId 2022091107 playId 3419
# Player masked for gameId 2022091106 playId 3116
# Player masked for gameId 2022091104 playId 2807
# Player masked for gameId 2022091105 playId 1850
# Player masked for gameId 2022091113 playId 510
# Player masked for gameId 2022091105 playId 3185
# Player masked for gameId 2022091100 playId 348
# Player masked for gameId 2022091102 playId 1265
# Player masked for gameId 2022091200 playId 1164
# Player masked for gameId 2022091108 playId 62
# Player masked for gameId 2022091101 playId 2386
# Player masked for gameId 2022090800 playId 3214
# Player masked for gameId 2022091107 playId 3323
# Player masked for gameId 2022091107 playId 3601
# Player masked for gameId 2022091113 playId 3995
# Player masked for gameId 2022091103 playId 1798
# Player masked for gameId 2022091200 playId 401
# Player masked for gameId 2022091108 playId 2119
# Player masked for gameId 2022091108 playId 1440
# Player masked for gameId 2022091111 playId 566
# Player masked for gameId 2022091102 playId 4019
# Player masked for gameId 2022091107 playId 660
# Player masked for gameId 2022091111 playId 379
# Player masked for gameId 2022091106 playId 792
# Player masked for gameId 2022091104 playId 4334
# Player masked for gameId 2022091104 playId 2516
# Player masked for gameId 2022090800 playId 3304
# Player masked for gameId 2022091113 playId 1984
# Player masked for gameId 2022091105 playId 503
# Player masked for gameId 2022091101 playId 251
# Player masked for gameId 2022091103 playId 4631
# Player masked for gameId 2022091112 playId 573
# Player masked for gameId 2022091112 playId 1260
# Player masked for gameId 2022091102 playId 4102
# Player masked for gameId 2022091101 playId 1879
# Player masked for gameId 2022091113 playId 3785
# Player masked for gameId 2022091113 playId 110
# Player masked for gameId 2022091105 playId 77
# Player masked for gameId 2022091110 playId 543
# Player masked for gameId 2022091105 playId 2153
# Player masked for gameId 2022091100 playId 2069
# Player masked for gameId 2022091100 playId 2090
# Player masked for gameId 2022091108 playId 445
# Player masked for gameId 2022091102 playId 3628
# Player masked for gameId 2022091111 playId 1484
# Player masked for gameId 2022090800 playId 438
# Player masked for gameId 2022091105 playId 56
# Player masked for gameId 2022090800 playId 721
# Player masked for gameId 2022091102 playId 531
# Player masked for gameId 2022091103 playId 1610
# Player masked for gameId 2022091100 playId 2899
# Player masked for gameId 2022091110 playId 102
# Player masked for gameId 2022091113 playId 465
# Player masked for gameId 2022091112 playId 2569
# Player masked for gameId 2022091101 playId 1338
# Player masked for gameId 2022091113 playId 3431
# Player masked for gameId 2022091105 playId 711
# Player masked for gameId 2022091102 playId 3828
# Player masked for gameId 2022091108 playId 3227
# Player masked for gameId 2022091200 playId 3325
# Player masked for gameId 2022091107 playId 1717
# Player masked for gameId 2022091113 playId 3455
# Player masked for gameId 2022091101 playId 708
# Player masked for gameId 2022091112 playId 2699
# Player masked for gameId 2022091103 playId 1405
# Player masked for gameId 2022091109 playId 539
# Player masked for gameId 2022091104 playId 558
# Player masked for gameId 2022091109 playId 163
# Player masked for gameId 2022091104 playId 2736
# Player masked for gameId 2022091103 playId 3825
# Player masked for gameId 2022091108 playId 1039
# Player masked for gameId 2022091107 playId 868
# Player masked for gameId 2022091200 playId 1988
# Player masked for gameId 2022091113 playId 3620
# Player masked for gameId 2022091113 playId 1170
# Player masked for gameId 2022091107 playId 4071
# Player masked for gameId 2022091103 playId 2414
# Player masked for gameId 2022091113 playId 3479
# Player masked for gameId 2022091111 playId 2464
# Player masked for gameId 2022091113 playId 444
# Player masked for gameId 2022091101 playId 1213
# Player masked for gameId 2022090800 playId 1286
# Player masked for gameId 2022091105 playId 3750
# Player masked for gameId 2022091108 playId 240
# Player masked for gameId 2022091103 playId 3779
# Player masked for gameId 2022091112 playId 3002
# Player masked for gameId 2022091108 playId 3774
# Player masked for gameId 2022091111 playId 3630
# Player masked for gameId 2022091111 playId 3295
# Player masked for gameId 2022091106 playId 904
# Player masked for gameId 2022091107 playId 1642
# Player masked for gameId 2022091112 playId 656
# Player masked for gameId 2022091200 playId 1967
# Player masked for gameId 2022091106 playId 2935
# Player masked for gameId 2022090800 playId 1208
# Player masked for gameId 2022091106 playId 2358
# Player masked for gameId 2022091110 playId 1560
# Player masked for gameId 2022091102 playId 343
# Player masked for gameId 2022091102 playId 595
# Player masked for gameId 2022091104 playId 2385
# Player masked for gameId 2022091102 playId 800
# Player masked for gameId 2022091109 playId 4029
# Player masked for gameId 2022091103 playId 1968
# Player masked for gameId 2022091100 playId 1466
# Player masked for gameId 2022091107 playId 3026
# Player masked for gameId 2022091103 playId 195
# Player masked for gameId 2022091106 playId 1995
# Player masked for gameId 2022091105 playId 3503
# Player masked for gameId 2022091200 playId 601
# Player masked for gameId 2022091112 playId 1501
# Player masked for gameId 2022091101 playId 438
# Player masked for gameId 2022090800 playId 2572
# Player masked for gameId 2022091110 playId 1312
# Player masked for gameId 2022091102 playId 3783
# Player masked for gameId 2022091106 playId 657
# Player masked for gameId 2022091109 playId 3177
# Player masked for gameId 2022091103 playId 3227
# Player masked for gameId 2022091109 playId 863
# Player masked for gameId 2022091109 playId 4286
# Player masked for gameId 2022091113 playId 3407
# Player masked for gameId 2022091102 playId 2352
# Player masked for gameId 2022091103 playId 2931
# Player masked for gameId 2022091113 playId 2307
# Player masked for gameId 2022091100 playId 1485
# Player masked for gameId 2022091110 playId 3071
# Player masked for gameId 2022091106 playId 175
# Player masked for gameId 2022091110 playId 569
# Player masked for gameId 2022091101 playId 3357
# Player masked for gameId 2022091113 playId 1742
# Player masked for gameId 2022091113 playId 2518
# Player masked for gameId 2022091111 playId 55
# Player masked for gameId 2022091109 playId 187
# Player masked for gameId 2022091107 playId 2200
# Player masked for gameId 2022091112 playId 133
# Player masked for gameId 2022091106 playId 2840
# Player masked for gameId 2022091102 playId 1029
# Player masked for gameId 2022091110 playId 2474
# Player masked for gameId 2022091107 playId 3811
# Player masked for gameId 2022091105 playId 619
# Player masked for gameId 2022091104 playId 1347
# Player masked for gameId 2022091104 playId 3640
# Player masked for gameId 2022091105 playId 424
# Player masked for gameId 2022091103 playId 1514
# Player masked for gameId 2022091200 playId 2370
# Player masked for gameId 2022091101 playId 993
# Player masked for gameId 2022091108 playId 815
# Player masked for gameId 2022091102 playId 2618
# Player masked for gameId 2022091101 playId 1744
# Player masked for gameId 2022091102 playId 3695
# Player masked for gameId 2022091104 playId 3059
# Player masked for gameId 2022091113 playId 1017
# Player masked for gameId 2022091105 playId 3971
# Player masked for gameId 2022091100 playId 1046
# Player masked for gameId 2022091105 playId 3387
# Player masked for gameId 2022091101 playId 2723
# Player masked for gameId 2022091100 playId 3757
# Player masked for gameId 2022091101 playId 599
# Player masked for gameId 2022091200 playId 156
# Player masked for gameId 2022091110 playId 1584
# Player masked for gameId 2022091102 playId 1050
# Player masked for gameId 2022091108 playId 1895
# Player masked for gameId 2022091105 playId 1701
# Player masked for gameId 2022091105 playId 2544
# Player masked for gameId 2022090800 playId 933
# Player masked for gameId 2022091100 playId 2616
# Player masked for gameId 2022091108 playId 3561
# Player masked for gameId 2022091105 playId 2742
# Player masked for gameId 2022091104 playId 1895
# Player masked for gameId 2022091112 playId 715
# Player masked for gameId 2022091110 playId 2765
# Player masked for gameId 2022091105 playId 4135
# Player masked for gameId 2022090800 playId 364
# Player masked for gameId 2022091200 playId 643
# Player masked for gameId 2022091113 playId 1038
# Player masked for gameId 2022091104 playId 3232
# Player masked for gameId 2022091100 playId 1672
# Player masked for gameId 2022091101 playId 2089
# Player masked for gameId 2022091100 playId 145
# Player masked for gameId 2022091111 playId 3554
# Player masked for gameId 2022091110 playId 1290
# Player masked for gameId 2022091103 playId 1384
# Player masked for gameId 2022091108 playId 3926
# Player masked for gameId 2022091103 playId 4657
# Player masked for gameId 2022091103 playId 446
# Player masked for gameId 2022091200 playId 1550
# Player masked for gameId 2022091110 playId 729
# Player masked for gameId 2022091101 playId 3080
# Player masked for gameId 2022091104 playId 2307
# Player masked for gameId 2022091111 playId 3525
# Player masked for gameId 2022091113 playId 2030
# Player masked for gameId 2022091104 playId 3662
# Player masked for gameId 2022091103 playId 2719
# Player masked for gameId 2022091105 playId 1809
# Player masked for gameId 2022091106 playId 950
# Player masked for gameId 2022091108 playId 1737
# Player masked for gameId 2022091113 playId 3601
# Player masked for gameId 2022091102 playId 2759
# Player masked for gameId 2022091113 playId 1631
# Player masked for gameId 2022091108 playId 968
# Player masked for gameId 2022091109 playId 4232
# Player masked for gameId 2022091106 playId 3529
# Player masked for gameId 2022091110 playId 4099
# Player masked for gameId 2022091107 playId 68
# Player masked for gameId 2022091113 playId 2077
# Player masked for gameId 2022091110 playId 291
# Player masked for gameId 2022091109 playId 1096
# Player masked for gameId 2022091200 playId 1217
# Player masked for gameId 2022091111 playId 2257
# Player masked for gameId 2022091112 playId 1360
# Player masked for gameId 2022091109 playId 1729
# Player masked for gameId 2022091109 playId 2678
# Player masked for gameId 2022091100 playId 1260
# Player masked for gameId 2022091101 playId 4128
# Player masked for gameId 2022091112 playId 1186
# Player masked for gameId 2022091109 playId 1002
# Player masked for gameId 2022091102 playId 1183
# Player masked for gameId 2022091105 playId 3094
# Player masked for gameId 2022091110 playId 844
# Player masked for gameId 2022091110 playId 76
# Player masked for gameId 2022091200 playId 2546
# Player masked for gameId 2022091112 playId 251
# Player masked for gameId 2022091110 playId 2720
# Player masked for gameId 2022091105 playId 4373
# Player masked for gameId 2022091103 playId 3079
# Player masked for gameId 2022091104 playId 2829
# Player masked for gameId 2022091110 playId 3578
# Player masked for gameId 2022091103 playId 58
# Player masked for gameId 2022091102 playId 2738
# Player masked for gameId 2022091200 playId 201
# Player masked for gameId 2022091200 playId 2244
# Player masked for gameId 2022091103 playId 3527
# Player masked for gameId 2022091107 playId 2934
# Player masked for gameId 2022091106 playId 154
# Player masked for gameId 2022091100 playId 546
# Player masked for gameId 2022091113 playId 3113
# Player masked for gameId 2022091106 playId 2474
# Player masked for gameId 2022091100 playId 1887
# Player masked for gameId 2022091100 playId 2353
# Player masked for gameId 2022091111 playId 3009
# Player masked for gameId 2022091105 playId 166
# Player masked for gameId 2022091110 playId 1256
# Player masked for gameId 2022091107 playId 1236
# Player masked for gameId 2022091102 playId 2923
# Player masked for gameId 2022091105 playId 1589
# Player masked for gameId 2022091108 playId 2426
# Player masked for gameId 2022091111 playId 952
# Player masked for gameId 2022091110 playId 219
# Player masked for gameId 2022091103 playId 111
# Player masked for gameId 2022091109 playId 4007
# Player masked for gameId 2022091106 playId 1040
# Player masked for gameId 2022091101 playId 772
# Player masked for gameId 2022091111 playId 2522
# ...
# Player masked for gameId 2022091107 playId 697
# Player masked for gameId 2022091108 playId 614
# Player masked for gameId 2022091107 playId 3475
# Player masked for gameId 2022091104 playId 3148
# Player masked for gameId 2022091112 playId 3589
# Player masked for gameId 2022090800 playId 1187
# Player masked for gameId 2022091110 playId 1494
# Player masked for gameId 2022091108 playId 1378
# Player masked for gameId 2022091105 playId 3603
# Player masked for gameId 2022091113 playId 2398
# Player masked for gameId 2022091100 playId 3355
# Player masked for gameId 2022091200 playId 2067
# Player masked for gameId 2022091113 playId 2933
# Player masked for gameId 2022091107 playId 511
# Player masked for gameId 2022091200 playId 2883
# Player masked for gameId 2022091109 playId 433
# Player masked for gameId 2022091109 playId 1705
# Player masked for gameId 2022091111 playId 1038
# Player masked for gameId 2022091102 playId 2894
# Player masked for gameId 2022091104 playId 1460
# Player masked for gameId 2022091108 playId 494
# Player masked for gameId 2022091106 playId 1401
# Player masked for gameId 2022091109 playId 316
# Player masked for gameId 2022091200 playId 1725
# Player masked for gameId 2022090800 playId 954
# Player masked for gameId 2022091104 playId 3776
# Player masked for gameId 2022091103 playId 3147
# Player masked for gameId 2022091108 playId 195
# Player masked for gameId 2022091110 playId 2925
# Player masked for gameId 2022091111 playId 3193
# Player masked for gameId 2022091107 playId 1596
# Player masked for gameId 2022091112 playId 484
# Player masked for gameId 2022091113 playId 3722
# Player masked for gameId 2022091107 playId 3835
# Player masked for gameId 2022091113 playId 1766
# Player masked for gameId 2022091111 playId 694
# Player masked for gameId 2022091109 playId 563
# Player masked for gameId 2022090800 playId 2755
# Player masked for gameId 2022091108 playId 2938
# Player masked for gameId 2022091103 playId 2462
# Player masked for gameId 2022091106 playId 2956
# Player masked for gameId 2022091102 playId 218
# Player masked for gameId 2022091200 playId 741
# Player masked for gameId 2022091112 playId 552
# Player masked for gameId 2022091102 playId 388
# Player masked for gameId 2022091111 playId 1124
# Player masked for gameId 2022091106 playId 859
# Player masked for gameId 2022091105 playId 1309
# Player masked for gameId 2022091104 playId 2928
# Player masked for gameId 2022091103 playId 1016
# Player masked for gameId 2022091106 playId 3050
# Player masked for gameId 2022091109 playId 839
# Player masked for gameId 2022091100 playId 2661
# Player masked for gameId 2022091104 playId 1826
# Player masked for gameId 2022091113 playId 2356
# Player masked for gameId 2022091107 playId 2844
# Player masked for gameId 2022091100 playId 395
# Player masked for gameId 2022091109 playId 462
# Player masked for gameId 2022091110 playId 913
# Player masked for gameId 2022091113 playId 708
# Player masked for gameId 2022091110 playId 400
# Player masked for gameId 2022091113 playId 1545
# Player masked for gameId 2022091112 playId 3029
# Player masked for gameId 2022091103 playId 4686
# Player masked for gameId 2022091102 playId 2302
# Player masked for gameId 2022091101 playId 339
# Player masked for gameId 2022091106 playId 1425
# Player masked for gameId 2022091105 playId 4171
# Player masked for gameId 2022091200 playId 1092
# Player masked for gameId 2022091102 playId 1204
# Player masked for gameId 2022091102 playId 3022
# Player masked for gameId 2022091107 playId 3575
# Player masked for gameId 2022091103 playId 2807
# Player masked for gameId 2022091200 playId 1579
# Player masked for gameId 2022091101 playId 2227
# Player masked for gameId 2022091104 playId 2492
# Player masked for gameId 2022091110 playId 3449
# Player masked for gameId 2022091111 playId 2901
# Player masked for gameId 2022091101 playId 1101
# Player masked for gameId 2022091200 playId 2500
# Player masked for gameId 2022091200 playId 3382
# Player masked for gameId 2022091105 playId 2303
# Player masked for gameId 2022091101 playId 109
# Player masked for gameId 2022091100 playId 3267
# Player masked for gameId 2022091107 playId 4171
# Player masked for gameId 2022091108 playId 1110
# Player masked for gameId 2022091106 playId 3253
# Player masked for gameId 2022091103 playId 1589
# Player masked for gameId 2022091113 playId 2598
# Player masked for gameId 2022091110 playId 460
# Player masked for gameId 2022091112 playId 1832
# Player masked for gameId 2022091109 playId 1219
# Player masked for gameId 2022091100 playId 2226
# Player masked for gameId 2022091200 playId 1487
# Player masked for gameId 2022091100 playId 1359
# Player masked for gameId 2022091100 playId 3028
# Player masked for gameId 2022091103 playId 82
# Player masked for gameId 2022091111 playId 1546
# Player masked for gameId 2022091104 playId 2641
# Player masked for gameId 2022091107 playId 3206
# Player masked for gameId 2022091107 playId 3277
# Player masked for gameId 2022091105 playId 962
# Player masked for gameId 2022091107 playId 1378
# Player masked for gameId 2022091108 playId 318
# Player masked for gameId 2022091109 playId 4096
# Player masked for gameId 2022091111 playId 1307
# Player masked for gameId 2022090800 playId 467
# Player masked for gameId 2022091111 playId 520
# Player masked for gameId 2022091104 playId 1481
# Player masked for gameId 2022091104 playId 3730
# Player masked for gameId 2022091105 playId 4755
# Player masked for gameId 2022091111 playId 3147
# Player masked for gameId 2022091104 playId 1273
# Player masked for gameId 2022090800 playId 2958
# Player masked for gameId 2022091112 playId 2501
# Player masked for gameId 2022091106 playId 1263
# Player masked for gameId 2022091200 playId 3173
# Player masked for gameId 2022090800 playId 1946
# Player masked for gameId 2022091112 playId 760
# Player masked for gameId 2022091109 playId 3116
# Player masked for gameId 2022091110 playId 1338
# Player masked for gameId 2022091104 playId 267
# Player masked for gameId 2022091102 playId 4189
# Player masked for gameId 2022091106 playId 3213
# Player masked for gameId 2022091200 playId 1320
# Player masked for gameId 2022091104 playId 4513
# Player masked for gameId 2022091106 playId 586
# Player masked for gameId 2022091106 playId 2215
# Player masked for gameId 2022091107 playId 911
# Player masked for gameId 2022091105 playId 527
# Player masked for gameId 2022091109 playId 2848
# Player masked for gameId 2022091110 playId 3231
# Player masked for gameId 2022090800 playId 1009
# Player masked for gameId 2022091104 playId 3286
# Player masked for gameId 2022091109 playId 2452
# Player masked for gameId 2022091200 playId 264
# Player masked for gameId 2022090800 playId 3617
# Player masked for gameId 2022091109 playId 1287
# Player masked for gameId 2022091101 playId 2452
# Player masked for gameId 2022091108 playId 839
# Player masked for gameId 2022091100 playId 1769
# Player masked for gameId 2022091111 playId 208
# Player masked for gameId 2022091112 playId 1281
# Player masked for gameId 2022091105 playId 2930
# Player masked for gameId 2022091103 playId 764
# Player masked for gameId 2022091104 playId 1938
# Player masked for gameId 2022091108 playId 83
# Player masked for gameId 2022091109 playId 4117
# Player masked for gameId 2022091103 playId 4462
# Player masked for gameId 2022091110 playId 2587
# Player masked for gameId 2022090800 playId 1230
# Player masked for gameId 2022091103 playId 2976
# Player masked for gameId 2022091112 playId 3530
# Player masked for gameId 2022091113 playId 1241
# Player masked for gameId 2022091105 playId 1613
# Player masked for gameId 2022091107 playId 1488
# Player masked for gameId 2022091113 playId 3555
# Player masked for gameId 2022091111 playId 3123
# Player masked for gameId 2022091110 playId 1163
# Player masked for gameId 2022091105 playId 1283
# Player masked for gameId 2022091113 playId 1587
# Player masked for gameId 2022091105 playId 4858
# Player masked for gameId 2022091112 playId 358
# Player masked for gameId 2022091101 playId 542
# Player masked for gameId 2022091109 playId 957
# Player masked for gameId 2022091108 playId 3251
# Player masked for gameId 2022091109 playId 4155
# Player masked for gameId 2022091100 playId 2374
# Player masked for gameId 2022091200 playId 3267
# Player masked for gameId 2022090800 playId 1563
# Player masked for gameId 2022091112 playId 508
# Player masked for gameId 2022091105 playId 1259
# Player masked for gameId 2022091104 playId 2329
# Player masked for gameId 2022091108 playId 3438
# Player masked for gameId 2022091200 playId 2591
# Player masked for gameId 2022091109 playId 1657
# Player masked for gameId 2022091103 playId 295
# Player masked for gameId 2022091101 playId 2341
# Player masked for gameId 2022091110 playId 1047
# Player masked for gameId 2022091113 playId 824
# Player masked for gameId 2022091113 playId 3853
# Player masked for gameId 2022091105 playId 3856
# Player masked for gameId 2022091103 playId 1249
# Player masked for gameId 2022091105 playId 3214
# Player masked for gameId 2022091105 playId 3293
# Player masked for gameId 2022091103 playId 1471
# Player masked for gameId 2022091113 playId 2672
# Player masked for gameId 2022091100 playId 828
# Player masked for gameId 2022091102 playId 86
# Player masked for gameId 2022090800 playId 2072
# Player masked for gameId 2022091112 playId 1741
# Player masked for gameId 2022091100 playId 1088
# Player masked for gameId 2022091102 playId 2415
# Player masked for gameId 2022091113 playId 732
# Player masked for gameId 2022091110 playId 2424
# Player masked for gameId 2022090800 playId 3455
# Player masked for gameId 2022091105 playId 2345
# Player masked for gameId 2022091106 playId 3298
# Player masked for gameId 2022091105 playId 4308
# Player masked for gameId 2022091104 playId 604
# Player masked for gameId 2022091104 playId 2683
# Player masked for gameId 2022091106 playId 359
# Player masked for gameId 2022091113 playId 1125
# Player masked for gameId 2022091102 playId 1609
# Player masked for gameId 2022090800 playId 1635
# Player masked for gameId 2022091109 playId 4051
# Player masked for gameId 2022091106 playId 523
# Player masked for gameId 2022091107 playId 1075
# Player masked for gameId 2022091102 playId 3470
# Player masked for gameId 2022091111 playId 3097
# Player masked for gameId 2022091107 playId 2551
# Player masked for gameId 2022091111 playId 1172
# Player masked for gameId 2022091105 playId 4707
# Player masked for gameId 2022090800 playId 3513
# Player masked for gameId 2022091113 playId 1812
# Player masked for gameId 2022091108 playId 2297
# Player masked for gameId 2022091105 playId 3949
# Player masked for gameId 2022091109 playId 1499
# Player masked for gameId 2022091101 playId 417
# Player masked for gameId 2022091100 playId 3201
# Player masked for gameId 2022090800 playId 2288
# Player masked for gameId 2022091109 playId 743
# Player masked for gameId 2022091113 playId 2446
# Player masked for gameId 2022091113 playId 3971
# Player masked for gameId 2022091109 playId 208
# Player masked for gameId 2022091108 playId 371
# Player masked for gameId 2022091200 playId 2009
# Player masked for gameId 2022091108 playId 2559
# Player masked for gameId 2022091111 playId 1946
# Player masked for gameId 2022091100 playId 3578
# Player masked for gameId 2022091112 playId 2680
# Player masked for gameId 2022091105 playId 4599
# Player masked for gameId 2022091103 playId 3890
# Player masked for gameId 2022090800 playId 122
# Player masked for gameId 2022090800 playId 2163
# Player masked for gameId 2022091113 playId 923
# Player masked for gameId 2022091108 playId 3318
# Player masked for gameId 2022090800 playId 1102
# Player masked for gameId 2022090800 playId 1334
# Player masked for gameId 2022091101 playId 2501
# Player masked for gameId 2022091112 playId 2072
# Player masked for gameId 2022091100 playId 3289
# Player masked for gameId 2022091103 playId 2433
# Player masked for gameId 2022091100 playId 2114
# Player masked for gameId 2022091100 playId 3177
# Player masked for gameId 2022091111 playId 336
# Player masked for gameId 2022091105 playId 1170
# Player masked for gameId 2022091101 playId 4174
# Player masked for gameId 2022091105 playId 936
# Player masked for gameId 2022091200 playId 1241
# Player masked for gameId 2022090800 playId 2934
# Player masked for gameId 2022091102 playId 2373
# Player masked for gameId 2022091112 playId 891
# Player masked for gameId 2022091110 playId 514
# Player masked for gameId 2022091105 playId 3625
# Player masked for gameId 2022091103 playId 2315
# Player masked for gameId 2022091103 playId 3849
# Player masked for gameId 2022091105 playId 1351
# Player masked for gameId 2022091200 playId 2093
# Player masked for gameId 2022091104 playId 488
# Player masked for gameId 2022091200 playId 882
# Player masked for gameId 2022091102 playId 239
# Player masked for gameId 2022091110 playId 750
# Player masked for gameId 2022091109 playId 2962
# Player masked for gameId 2022091110 playId 1092
# Player masked for gameId 2022091104 playId 2154
# Player masked for gameId 2022091108 playId 2657
# Player masked for gameId 2022091200 playId 1642
# Player masked for gameId 2022091200 playId 1344
# Player masked for gameId 2022091113 playId 756
# Player masked for gameId 2022091110 playId 1515
# Player masked for gameId 2022091111 playId 2633
# Player masked for gameId 2022091103 playId 2336
# Player masked for gameId 2022091102 playId 989
# Player masked for gameId 2022091104 playId 3572
# Player masked for gameId 2022091107 playId 1399
# Player masked for gameId 2022091103 playId 3755
# Player masked for gameId 2022091106 playId 3138
# Player masked for gameId 2022091103 playId 4710
# Player masked for gameId 2022091100 playId 2878
# Player masked for gameId 2022091111 playId 360
# Player masked for gameId 2022091100 playId 2303
# Player masked for gameId 2022091106 playId 59
# Player masked for gameId 2022091104 playId 910
# Player masked for gameId 2022091102 playId 1133
# Player masked for gameId 2022091104 playId 2877
# Player masked for gameId 2022091102 playId 2783
# Player masked for gameId 2022091103 playId 340
# Player masked for gameId 2022091111 playId 1612
# Player masked for gameId 2022091105 playId 1913
# Player masked for gameId 2022091112 playId 2886
# Player masked for gameId 2022091110 playId 2356
# Player masked for gameId 2022091111 playId 665
# Player masked for gameId 2022091106 playId 883
# Player masked for gameId 2022091110 playId 1068
# Player masked for gameId 2022091107 playId 2457
# Player masked for gameId 2022091109 playId 2245
# Player masked for gameId 2022091105 playId 4352
# Player masked for gameId 2022091102 playId 3899
# Player masked for gameId 2022090800 playId 3262
# Player masked for gameId 2022091100 playId 1952
# Player masked for gameId 2022091105 playId 1029
# Player masked for gameId 2022091110 playId 55
# Player masked for gameId 2022091102 playId 2639
# Player masked for gameId 2022091101 playId 3399
# Player masked for gameId 2022091108 playId 1974
# Player masked for gameId 2022091113 playId 2790
# Player masked for gameId 2022091109 playId 2614
# Player masked for gameId 2022091200 playId 1004
# Player masked for gameId 2022091110 playId 2148
# Player masked for gameId 2022091104 playId 3821
# Player masked for gameId 2022091101 playId 1036
# Player masked for gameId 2022090800 playId 3166
# Player masked for gameId 2022091104 playId 1660
# Player masked for gameId 2022091109 playId 4575
# Player masked for gameId 2022091111 playId 2922
# Player masked for gameId 2022091100 playId 2595
# Player masked for gameId 2022091100 playId 2640
# Player masked for gameId 2022090800 playId 2336
# Player masked for gameId 2022091103 playId 2851
# Player masked for gameId 2022091108 playId 1015
# Player masked for gameId 2022091105 playId 1194
# Player masked for gameId 2022091102 playId 2281
# Player masked for gameId 2022091111 playId 1148
# Player masked for gameId 2022091113 playId 2180
# Player masked for gameId 2022091105 playId 336
# Player masked for gameId 2022091105 playId 1518
# Player masked for gameId 2022091102 playId 1794
# Player masked for gameId 2022091102 playId 1815
# Player masked for gameId 2022091100 playId 522
# Player masked for gameId 2022090800 playId 212
# Player masked for gameId 2022091110 playId 2287
# Player masked for gameId 2022091110 playId 2085
# Player masked for gameId 2022090800 playId 236
# Player masked for gameId 2022091105 playId 3345

# %%
maskedPlayers_df.head()
# Out:
# shape: (5, 23)
# ┌────────────┬────────┬───────┬───────────────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName       ┆ … ┆ vx       ┆ vy       ┆ ox       ┆ oy       │
# │ ---        ┆ ---    ┆ ---   ┆ ---               ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64        ┆ i64    ┆ i64   ┆ str               ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞════════════╪════════╪═══════╪═══════════════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 2022091105 ┆ 3345   ┆ 52498 ┆ Jonathan Greenard ┆ … ┆ 2.40592  ┆ 4.394502 ┆ 0.357227 ┆ 0.934018 │
# │ 2022091105 ┆ 3345   ┆ 52498 ┆ Jonathan Greenard ┆ … ┆ 2.413586 ┆ 4.390296 ┆ 0.357227 ┆ 0.934018 │
# │ 2022091105 ┆ 3345   ┆ 52498 ┆ Jonathan Greenard ┆ … ┆ 2.393259 ┆ 4.378631 ┆ 0.326888 ┆ 0.945063 │
# │ 2022091105 ┆ 3345   ┆ 52498 ┆ Jonathan Greenard ┆ … ┆ 2.353002 ┆ 4.366347 ┆ 0.304033 ┆ 0.952661 │
# │ 2022091105 ┆ 3345   ┆ 52498 ┆ Jonathan Greenard ┆ … ┆ 2.398025 ┆ 4.44432  ┆ 0.316477 ┆ 0.9486   │
# └────────────┴────────┴───────┴───────────────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %%
tracking_df.head()
# Out:
# shape: (5, 23)
# ┌────────────┬────────┬───────┬────────────────┬───┬──────────┬──────────┬───────────┬───────────┐
# │ gameId     ┆ playId ┆ nflId ┆ displayName    ┆ … ┆ vx       ┆ vy       ┆ ox        ┆ oy        │
# │ ---        ┆ ---    ┆ ---   ┆ ---            ┆   ┆ ---      ┆ ---      ┆ ---       ┆ ---       │
# │ i64        ┆ i64    ┆ i64   ┆ str            ┆   ┆ f64      ┆ f64      ┆ f64       ┆ f64       │
# ╞════════════╪════════╪═══════╪════════════════╪═══╪══════════╪══════════╪═══════════╪═══════════╡
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.669161 ┆ 0.265751 ┆ -0.914748 ┆ -0.404024 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.672161 ┆ 0.228691 ┆ -0.909309 ┆ -0.416122 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.647975 ┆ 0.237125 ┆ -0.902209 ┆ -0.431299 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.621126 ┆ 0.251203 ┆ -0.902209 ┆ -0.431299 │
# │ 2022091200 ┆ 64     ┆ 35459 ┆ Kareem Jackson ┆ … ┆ 0.578276 ┆ 0.296811 ┆ -0.91169  ┆ -0.410878 │
# └────────────┴────────┴───────┴────────────────┴───┴──────────┴──────────┴───────────┴───────────┘

# %% [markdown]
# ## Splitting data into train, validation, and test sets.

# %%
# Provided from SportsTransformers-utils

def split_train_test_val(tracking_df: pl.DataFrame, target_df: pl.DataFrame) -> dict[str, pl.DataFrame]:
    """
    Split data into train, validation, and test sets.
    Split is 70-15-15 for train-test-val respectively. Notably, we split at the play levle and not frame level.
    This ensures no target contamination between splits.

    Args:
        tracking_df (pl.DataFrame): Tracking data
        target_df (pl.DataFrame): Target data

    Returns:
        dict: Dictionary containing train, validation, and test dataframes.
    """
    tracking_df = tracking_df.sort(["gameId", "playId", "frameId"])
    target_df = target_df.sort(["gameId", "playId"])

    print(
        f"Total set: {tracking_df.n_unique(['gameId', 'playId'])} plays,",
        f"{tracking_df.n_unique(['gameId', 'playId', 'frameId'])} frames",
    )

    test_val_ids = tracking_df.select(["gameId", "playId"]).unique(maintain_order=True).sample(fraction=0.3, seed=42)
    train_tracking_df = tracking_df.join(test_val_ids, on=["gameId", "playId"], how="anti")
    train_tgt_df = target_df.join(test_val_ids, on=["gameId", "playId"], how="anti")
    print(
        f"Train set: {train_tracking_df.n_unique(['gameId', 'playId'])} plays,",
        f"{train_tracking_df.n_unique(['gameId', 'playId', 'frameId'])} frames",
    )

    test_ids = test_val_ids.sample(fraction=0.5, seed=42)  # 70-15-15 split
    test_tracking_df = tracking_df.join(test_ids, on=["gameId", "playId"], how="inner")
    test_tgt_df = target_df.join(test_ids, on=["gameId", "playId"], how="inner")
    print(
        f"Test set: {test_tracking_df.n_unique(['gameId', 'playId'])} plays,",
        f"{test_tracking_df.n_unique(['gameId', 'playId', 'frameId'])} frames",
    )

    val_ids = test_val_ids.join(test_ids, on=["gameId", "playId"], how="anti")
    val_tracking_df = tracking_df.join(val_ids, on=["gameId", "playId"], how="inner")
    val_tgt_df = target_df.join(val_ids, on=["gameId", "playId"], how="inner")
    print(
        f"Validation set: {val_tracking_df.n_unique(['gameId', 'playId'])} plays,",
        f"{val_tracking_df.n_unique(['gameId', 'playId','frameId'])} frames",
    )

    return {
        "train_features": train_tracking_df,
        "train_targets": train_tgt_df,
        "test_features": test_tracking_df,
        "test_targets": test_tgt_df,
        "val_features": val_tracking_df,
        "val_targets": val_tgt_df,
    }

# %%
# Writing out splits to OUT_DIR

print("Split train/test/val")
split_dfs = split_train_test_val(rel_tracking_df, maskedPlayers_df)

out_dir = Path(OUT_DIR)
out_dir.mkdir(exist_ok=True, parents=True)

for key, df in split_dfs.items():
    sort_keys = ["gameId", "playId", "frameId"]
    df.sort(sort_keys).write_parquet(out_dir / f"{key}.parquet")
# Out:
# Split train/test/val
# Total set: 1952 plays, 308900 frames
# Train set: 1367 plays, 214793 frames
# Test set: 292 plays, 46712 frames
# Validation set: 293 plays, 47395 frames
